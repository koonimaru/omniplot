# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import statannot

# %%
df=sns.load_dataset("penguins")
df=df.dropna(axis=0)

# %%
fig, ax=plt.subplots(figsize=(6,6))
sns.violinplot(data=df, x="species",y="bill_depth_mm", inner="quartile", color="gray", ax=ax)
sns.swarmplot(data=df, x="species",y="bill_depth_mm", color="black", size=3, ax=ax)
statannot.add_stat_annotation(ax, data=df, x="species",y="bill_depth_mm", box_pairs=[("Adelie","Chinstrap"),("Adelie","Gentoo"),("Chinstrap","Gentoo")], test='Mann-Whitney', text_format='star', loc='inside', verbose=2)
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# Adelie v.s. Chinstrap: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=4.701e+03
# Chinstrap v.s. Gentoo: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.977e-28 U_stat=8.018e+03
# Adelie v.s. Gentoo: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.221e-41 U_stat=1.712e+04
# (<Axes: xlabel='species', ylabel='bill_depth_mm'>,
# ...
#   <statannot.StatResult.StatResult at 0x7f0b49a337c0>])

# %%
# !pip install bioinfokit
# Out:
# Collecting bioinfokit
#   Downloading bioinfokit-2.1.4.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.1/88.1 kB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /home/koh/.local/lib/python3.10/site-packages (from bioinfokit) (2.2.3)
# Requirement already satisfied: numpy in /home/koh/.local/lib/python3.10/site-packages (from bioinfokit) (1.26.4)
# Requirement already satisfied: matplotlib in /home/koh/anaconda3/envs/omniplot310/lib/python3.10/site-packages (from bioinfokit) (3.7.1)
# Requirement already satisfied: scipy in /home/koh/anaconda3/envs/omniplot310/lib/python3.10/site-packages (from bioinfokit) (1.14.0)
# Requirement already satisfied: scikit-learn in /home/koh/.local/lib/python3.10/site-packages (from bioinfokit) (1.2.2)
# Requirement already satisfied: seaborn in /home/koh/anaconda3/envs/omniplot310/lib/python3.10/site-packages (from bioinfokit) (0.13.2)
# Collecting matplotlib-venn (from bioinfokit)
#   Downloading matplotlib-venn-1.1.1.tar.gz (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 3.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tabulate in /home/koh/.local/lib/python3.10/site-packages (from bioinfokit) (0.9.0)
# Requirement already satisfied: statsmodels in /home/koh/.local/lib/python3.10/site-packages (from bioinfokit) (0.13.5)
# Collecting textwrap3 (from bioinfokit)
#   Downloading textwrap3-0.9.2-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: adjustText in /home/koh/.local/lib/python3.10/site-packages (from bioinfokit) (0.8)
# Requirement already satisfied: contourpy>=1.0.1 in /home/koh/anaconda3/envs/omniplot310/lib/python3.10/site-packages (from matplotlib->bioinfokit) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/koh/anaconda3/envs/omniplot310/lib/python3.10/site-packages (from matplotlib->bioinfokit) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/koh/anaconda3/envs/omniplot310/lib/python3.10/site-packages (from matplotlib->bioinfokit) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/koh/anaconda3/envs/omniplot310/lib/python3.10/site-packages (from matplotlib->bioinfokit) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/koh/anaconda3/envs/omniplot310/lib/python3.10/site-packages (from matplotlib->bioinfokit) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/koh/anaconda3/envs/omniplot310/lib/python3.10/site-packages (from matplotlib->bioinfokit) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/koh/anaconda3/envs/omniplot310/lib/python3.10/site-packages (from matplotlib->bioinfokit) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/koh/.local/lib/python3.10/site-packages (from matplotlib->bioinfokit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/koh/anaconda3/envs/omniplot310/lib/python3.10/site-packages (from pandas->bioinfokit) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in /home/koh/.local/lib/python3.10/site-packages (from pandas->bioinfokit) (2024.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/koh/.local/lib/python3.10/site-packages (from scikit-learn->bioinfokit) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/koh/.local/lib/python3.10/site-packages (from scikit-learn->bioinfokit) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /home/koh/.local/lib/python3.10/site-packages (from statsmodels->bioinfokit) (0.5.3)
# Requirement already satisfied: six in /home/koh/anaconda3/envs/omniplot310/lib/python3.10/site-packages (from patsy>=0.5.2->statsmodels->bioinfokit) (1.16.0)
# Downloading textwrap3-0.9.2-py2.py3-none-any.whl (12 kB)
# Building wheels for collected packages: bioinfokit, matplotlib-venn
#   Building wheel for bioinfokit (setup.py) ... done
#   Created wheel for bioinfokit: filename=bioinfokit-2.1.4-py3-none-any.whl size=59218 sha256=fd20c9fbe8aef01ddada9e64400276a4d8bfb7214ab2f86e45b3544c3cdc4e0d
#   Stored in directory: /home/koh/.cache/pip/wheels/45/b1/91/212510cab723ee76a25180836e8897f926820382374184b017
#   Building wheel for matplotlib-venn (pyproject.toml) ... done
#   Created wheel for matplotlib-venn: filename=matplotlib_venn-1.1.1-py3-none-any.whl size=45288 sha256=888b8153e647817de34219de9d080ed354b3e3da80687b4e2bd9b1bc6ffc81eb
#   Stored in directory: /home/koh/.cache/pip/wheels/3c/b6/e2/5fadaf4aa63fac5b079d4f633e9d96b29a67ee4fae816806f3
# Successfully built bioinfokit matplotlib-venn
# Installing collected packages: textwrap3, matplotlib-venn, bioinfokit
# Successfully installed bioinfokit-2.1.4 matplotlib-venn-1.1.1 textwrap3-0.9.2

# %%
from bioinfokit import analys, visuz

# load dataset as pandas dataframe
df = analys.get_data("volcano").data

# %%
df
# Out:
#               GeneNames    log2FC       p-value
# 0      LOC_Os09g01000.1 -1.886539  1.250000e-55
# 1      LOC_Os12g42876.1  3.231611  1.050000e-55
# 2      LOC_Os12g42884.2  3.179004  2.590000e-54
# 3      LOC_Os03g16920.1  5.290677  4.690000e-54
# 4      LOC_Os05g47540.4  4.096862  2.190000e-54
# ...                 ...       ...           ...
# 10632  LOC_Os04g13900.1  0.000000  1.000000e+00
# 10633  LOC_Os02g10920.4  0.000000  1.000000e+00
# 10634  LOC_Os01g08350.1  0.000000  1.000000e+00
# 10635  LOC_Os03g17250.1  0.000000  1.000000e+00
# 10636  LOC_Os01g07560.1  0.000000  1.000000e+00
#
# [10637 rows x 3 columns]

# %%
from omniplot import plot as op

res = op.volcanoplot(
    df=df,
    x="log2FC",
    y="p-value",
    label="GeneNames",
    xthreshold=2,
    ythreshold=0.0001,
    base_color="gray",
)
# Out:
# Transforming p-value to -log10 values. if you do not want it, set 'logscaley=False'.

# %%
df
# Out:
#               GeneNames    log2FC       p-value
# 0      LOC_Os09g01000.1 -1.886539  1.250000e-55
# 1      LOC_Os12g42876.1  3.231611  1.050000e-55
# 2      LOC_Os12g42884.2  3.179004  2.590000e-54
# 3      LOC_Os03g16920.1  5.290677  4.690000e-54
# 4      LOC_Os05g47540.4  4.096862  2.190000e-54
# ...                 ...       ...           ...
# 10632  LOC_Os04g13900.1  0.000000  1.000000e+00
# 10633  LOC_Os02g10920.4  0.000000  1.000000e+00
# 10634  LOC_Os01g08350.1  0.000000  1.000000e+00
# 10635  LOC_Os03g17250.1  0.000000  1.000000e+00
# 10636  LOC_Os01g07560.1  0.000000  1.000000e+00
#
# [10637 rows x 3 columns]

# %%
res
# Out:
# {'upgenes':      index         GeneNames    log2FC    p-value
#  0        1  LOC_Os12g42876.1  3.231611  54.978811
#  1        2  LOC_Os12g42884.2  3.179004  53.586700
#  2        3  LOC_Os03g16920.1  5.290677  53.328827
#  3        4  LOC_Os05g47540.4  4.096862  53.659556
#  4        6  LOC_Os01g62900.1  5.592457  53.806875
#  ..     ...               ...       ...        ...
#  777   1638  LOC_Os05g24020.1  1.263034   1.319263
#  778   1639  LOC_Os02g41860.1  1.263034   1.319263
#  779   1643  LOC_Os12g40190.1  1.000000   1.309588
#  780   1644  LOC_Os02g02320.1  1.000000   1.309588
#  781   1645  LOC_Os07g48290.2  1.000000   1.309588
#
#  [782 rows x 4 columns],
#  'downgenes':      index         GeneNames    log2FC    p-value
#  0        0  LOC_Os09g01000.1 -1.886539  54.903090
#  1        5  LOC_Os09g00999.1 -1.839222  53.709965
#  2       13  LOC_Os03g03720.1 -1.764669  40.263603
#  3       15  LOC_Os02g02400.3 -2.236574  39.732828
#  4       21  LOC_Os12g19381.1 -2.339576  31.744727
#  ..     ...               ...       ...        ...
#  535   1677  LOC_Os06g37180.1 -3.000000   1.311937
#  536   1678  LOC_Os01g61814.1 -3.000000   1.311937
#  537   1679  LOC_Os03g04590.1 -3.000000   1.311937
#  538   1680  LOC_Os11g47470.1 -3.000000   1.311937
#  539   1681  LOC_Os09g09770.1 -3.000000   1.311937
#
#  [540 rows x 4 columns],
#  'labeledgenes': [    index         GeneNames    log2FC    p-value
#   4       6  LOC_Os01g62900.1  5.592457  53.806875
#   2       3  LOC_Os03g16920.1  5.290677  53.328827
#   3       4  LOC_Os05g47540.4  4.096862  53.659556
#   19     26  LOC_Os05g39250.1  5.392317  26.343902
#   15     19  LOC_Os05g47540.1  4.832890  34.034798,
#       index         GeneNames    log2FC    p-value
#   42    135  LOC_Os09g26810.1 -4.459432   8.847712
#   45    145  LOC_Os12g31000.1 -4.392317   8.338187
#   58    199  LOC_Os10g40700.1 -4.954196   6.649752
#   28     90  LOC_Os01g59150.1 -3.584963  11.987163
#   39    129  LOC_Os06g15330.1 -3.700440   9.038105]}

# %%
import seaborn as sns
from omniplot import plot as op

# %%
df = sns.load_dataset("penguins")
df = df.dropna(axis=0)
op.violinplot(
    df,
    x="species",
    y="bill_length_mm",
    pairs=[["Adelie", "Chinstrap"], ["Gentoo", "Chinstrap"], ["Adelie", "Gentoo"]],
    test="mannwhitneyu",
    significance="symbol",
    swarm=True,
)
# Out:
# /home/koh/vscode/omniplot/omniplot/plot.py:364: UserWarning: You have used the `textcoords` kwarg, but not the `xytext` kwarg.  This can lead to surprising results.
#   ax.annotate(

# %%
df = sns.load_dataset("penguins")
df = df.dropna(axis=0)
op.violinplot2(
    df,
    x="species",
    y="bill_length_mm",
    pairs=[["Adelie", "Chinstrap"], ["Gentoo", "Chinstrap"], ["Adelie", "Gentoo"]],
    test="mannwhitneyu",
    significance="symbol",
    swarm=True,
)
# Out:
# /home/koh/vscode/omniplot/omniplot/plot.py:597: UserWarning: You have used the `textcoords` kwarg, but not the `xytext` kwarg.  This can lead to surprising results.
#   ax.annotate(
# {'p values': {'Adelie_Chinstrap': 30.04,
#   'Chinstrap_Gentoo': 2.53,
#   'Adelie_Gentoo': 41.69},
#  'axes': <Axes: >}

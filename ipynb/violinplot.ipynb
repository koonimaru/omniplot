# %%
import seaborn as sns
from omniplot import plot as op

# %%
df = sns.load_dataset("penguins")
df = df.dropna(axis=0)
op.violinplot(
    df,
    x="species",
    y="bill_length_mm",
    pairs=[["Adelie", "Chinstrap"], ["Gentoo", "Chinstrap"], ["Adelie", "Gentoo"]],
    test="mannwhitneyu",
    significance="symbol",
    swarm=True,
)
# Out:
# /home/koh/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/koh/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/koh/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/koh/vscode/omniplot/omniplot/plot.py:366: UserWarning: You have used the `textcoords` kwarg, but not the `xytext` kwarg.  This can lead to surprising results.
#   "\n".join(

# %%
df = sns.load_dataset("penguins")
df = df.dropna(axis=0)
op.violinplot2(
    df,
    x="species",
    y="bill_length_mm",
    pairs=[["Adelie", "Chinstrap"], ["Gentoo", "Chinstrap"], ["Adelie", "Gentoo"]],
    test="mannwhitneyu",
    significance="symbol",
    swarm=True,
)
# Out:
# /home/koh/vscode/omniplot/omniplot/plot.py:599: UserWarning: You have used the `textcoords` kwarg, but not the `xytext` kwarg.  This can lead to surprising results.
#   "\n".join(
# {'p values': {'Adelie_Chinstrap': 30.04,
#   'Chinstrap_Gentoo': 2.53,
#   'Adelie_Gentoo': 41.69},
#  'axes': <Axes: >}

# %%
import seaborn as sns
from omniplot import plot as op

# %%
df=sns.load_dataset("penguins")
df=df.dropna(axis=0)
op.violinplot(df,x="species",y="bill_length_mm", 
           pairs=[["Adelie","Chinstrap" ],["Gentoo","Chinstrap" ],["Adelie","Gentoo" ]],
           test="mannwhitneyu",
           significance="symbol",swarm=True)
# Out:
# /home/koh/.local/lib/python3.8/site-packages/omniplot/plot.py:1460: UserWarning: You have used the `textcoords` kwarg, but not the `xytext` kwarg.  This can lead to surprising results.
#   ax.annotate("\n".join(["{}: p < {:.2E}".format(k, 10**(-significance_ranges[k])) for k in keys]),
# {'p values': {'Adelie_Chinstrap': 30.04,
#   'Chinstrap_Gentoo': 2.53,
#   'Adelie_Gentoo': 41.69},
#  'ax': <AxesSubplot:xlabel='species', ylabel='bill_length_mm'>}

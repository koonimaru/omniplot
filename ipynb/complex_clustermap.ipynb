# %% [markdown]
# Drawing complex heatmap with clustering

# %%
import seaborn as sns
from omniplot import plot as op
import pandas as pd
import numpy as np

# %% [markdown]
# in the case, you want to use GUI, put the following line in to the code block
# ```
# %matplotlib tk
# ```
# for macos, "%matplotlib qt5" may work after installing pyqt5 with pip

# %%
# %config InlineBackend.print_figure_kwargs={'bbox_inches': None}

# %%
df=sns.load_dataset("penguins")
    
df=df.dropna(axis=0)
# df=df.reset_index(drop=True)
res=op.heatmap(df=df, variables=["bill_length_mm","bill_depth_mm","flipper_length_mm"],row_split=True, clustering_method="hierarchical",
            category=["species", "island"],col_colors={"organ": ["bill","bill","flipper"]}, row_plot=["body_mass_g"], row_ticklabels=False, approx_clusternum=3)
# Out:
# Assuming data is a wide form
# figsize:  [5.0, 10.0]
# [0.1, 0.15, 0.29999999999999993, 0.15]
# /home/koh/anaconda3/envs/omniplot310t/lib/python3.10/site-packages/omniplot/heatmap.py:2207: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Y = sch.linkage(D, method=method)
# /home/koh/anaconda3/envs/omniplot310t/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: There are no gridspecs with layoutgrids. Possibly did not call parent GridSpec with the "figure" keyword
#   func(*args, **kwargs)
# /home/koh/anaconda3/envs/omniplot310t/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: There are no gridspecs with layoutgrids. Possibly did not call parent GridSpec with the "figure" keyword
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
res=op.heatmap(df=df, variables=["bill_length_mm","bill_depth_mm","flipper_length_mm"],row_split=True, clustering_method="kmeans",
            category=["species", "island"],col_colors={"organ": ["bill","bill","flipper"]}, row_plot=["body_mass_g"], row_ticklabels=False, approx_clusternum=3)
# Out:
# Assuming data is a wide form
# figsize:  [5.0, 10.0]
# [0.1, 0.15, 0.24999999999999997, 0.15]
# /home/koh/anaconda3/envs/omniplot310t/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: There are no gridspecs with layoutgrids. Possibly did not call parent GridSpec with the "figure" keyword
#   func(*args, **kwargs)
# /home/koh/anaconda3/envs/omniplot310t/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: There are no gridspecs with layoutgrids. Possibly did not call parent GridSpec with the "figure" keyword
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
res=op.heatmap(df=df, dtype="categorical", variables=["species", "island", "sex"],
            row_plot=["body_mass_g"], row_ticklabels=False, approx_clusternum=3,column_wise_color=True)
# Out:
# Assuming data is a wide form
# Categorical variables are provided. 'kmodes' will be used for the clustering method.
# figsize:  [5.0, 10.0]
# [0.1, 0.15, 0.35, 0.15]
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 83, cost: 260.0
# Run 1, iteration: 2/100, moves: 0, cost: 260.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 58, cost: 255.0
# Run 2, iteration: 2/100, moves: 0, cost: 255.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 34, cost: 217.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 83, cost: 242.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 22, cost: 311.0
# Best run was number 3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# /home/koh/anaconda3/envs/omniplot310t/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: There are no gridspecs with layoutgrids. Possibly did not call parent GridSpec with the "figure" keyword
#   func(*args, **kwargs)
# /home/koh/anaconda3/envs/omniplot310t/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: There are no gridspecs with layoutgrids. Possibly did not call parent GridSpec with the "figure" keyword
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
mat=np.concatenate([0.25*np.random.uniform(0,1,size=[10, 25]),0.5*np.random.uniform(0,1,size=[15, 25]),
                    np.random.uniform(0,1,size=[15, 25])])
df=pd.DataFrame(mat)
res=op.heatmap(df, sizes=mat, 
            row_split=True,
            row_plot={"normal": np.random.normal(size=mat.shape[0])}, 
            row_scatter={"uniform": np.random.uniform(size=mat.shape[0])}, 
            row_bar={"range": np.arange(mat.shape[0])},
            col_bar={"range": np.arange(mat.shape[1])},
            
            edgecolor=None, approx_clusternum=3, ztranform=False)
# Out:
# Assuming data is a wide form
# figsize:  [6.0, 8.0]
# [0.1, 0.15, 0.29999999999999993, 0.15]
# scaled:  0.0 1.0
# _sy 200
# 0.007999999999999998 0.1
# 0.039999999999999994 0.5
# 0.07999999999999999 1.0

# %%
res=op.heatmap(df,shape="circle", 
               sizes=mat, 
            row_split=True,
            row_plot={"normal": np.random.normal(size=mat.shape[0])}, 
            row_scatter={"uniform": np.random.uniform(size=mat.shape[0])}, 
            row_bar={"range": np.arange(mat.shape[0])},
            col_bar={"range": np.arange(mat.shape[1])},
            
            edgecolor=None, approx_clusternum=3, ztranform=False)
# Out:
# Assuming data is a wide form
# figsize:  [6.0, 8.0]
# [0.1, 0.15, 0.29999999999999993, 0.15]
# scaled:  0.0 1.0
# _sy 200
# 0.007999999999999998 0.1
# 0.039999999999999994 0.5
# 0.07999999999999999 1.0

# %%
# op.heatmap(df, shape="circle", sizes=mat, edgecolor=None, approx_clusternum=3, row_split=True, ztranform=False)
mat=np.arange(50).reshape([5,10]).astype(np.float)
df=pd.DataFrame(mat)
op.heatmap(df, shape="triangle", sizes=mat, row_cluster=False,col_cluster=False, edgecolor=None, approx_clusternum=3, ztranform=False, row_split=True)
# Out:
# Assuming data is a wide form
# figsize:  [7.0, 3.0]
# [0.1, 0, 0.6, 0.15]
# scaled:  0.0 1.0
# _sy 200
# 0.04 0.1
# 0.2 0.5
# 0.4 1.0
# /tmp/ipykernel_30120/2936870297.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mat=np.arange(50).reshape([5,10]).astype(np.float)
# {'row_clsuter': {}, 'col_cluster': {}}

# %%
df=sns.load_dataset("penguins")

df=df.dropna(axis=0)
dfcol=pd.DataFrame({"features":["bill","bill","flipper"]})
res=op.complex_clustermap(df,dfcol=dfcol,

                    variables=["bill_length_mm","bill_depth_mm","flipper_length_mm"],
                    row_colors=["species","sex"],
                    row_scatter=["body_mass_g"],
                    row_plot=["body_mass_g"],
                    row_bar=["body_mass_g"],
                    col_colors=["features"],
                    approx_clusternum=3, figsize=[6,6],
                    marginalsum=True)
# Out:
# 33.30994610428297
# ['#393b79', '#6b6ecf', '#8ca252']

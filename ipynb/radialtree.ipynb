# %%
import seaborn as sns
from omniplot import plot as op

# %%
df=sns.load_dataset("penguins")
df=df.dropna(axis=0)
res=op.radialtree(df, category=["species","island","sex"])
# Out:
# /home/koh/anaconda3/envs/omniplot310t/lib/python3.10/site-packages/omniplot/plot.py:146: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Y = sch.linkage(D, method=tree_method)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/koh/vscode/omniplot/ipynb/radialtree.ipynb Cell 2 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/home/koh/vscode/omniplot/ipynb/radialtree.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> df=sns.load_dataset("penguins")
#       <a href='vscode-notebook-cell:/home/koh/vscode/omniplot/ipynb/radialtree.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> df=df.dropna(axis=0)
# ----> <a href='vscode-notebook-cell:/home/koh/vscode/omniplot/ipynb/radialtree.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> res=op.radialtree(df, category=["species","island","sex"])
#
# File ~/anaconda3/envs/omniplot310t/lib/python3.10/site-packages/omniplot/plot.py:154, in radialtree(df, n_clusters, x, variables, category, ztransform, save, distance_method, tree_method, title, y, **kwargs)
#     150 Z=sch.dendrogram(Y,
#     151                     labels = _labels,
#     152                     color_threshold=t,no_plot=True)
#     153 sample_classes={k: list(category_df[k]) for k in category_df.columns}
# --> 154 ax=_radialtree2(Z, sample_classes=sample_classes,addlabels=False, **kwargs)
#     155 if title !="":
#     156     ax.set_title(title)
#
# File ~/anaconda3/envs/omniplot310t/lib/python3.10/site-packages/omniplot/utils.py:663, in _radialtree2(Z2, fontsize, figsize, palette, addlabels, show, sample_classes, colorlabels, colorlabels_legend)
#     660     theta=(2*np.pi/360)*((_rotr*0.5+_rot*0.5)-(_rotl*0.5+_rot*0.5))
#     661     #print(start, theta,_rotl, _rotr)
#     662     #print(start, theta, innerrad, outerrad,10, _colorlist[i])
# --> 663     _baumkuchen(ax, start, theta, innerrad, outerrad,10, _colorlist[i])
#     665 # patches, texts =plt.pie(colorpos, colors=_colorlist,
#     666 #         radius=outerrad,
#     667 #         counterclock=True,
#     668 #         startangle=label_coords[0][2]*0.5)
#     669 # circle=plt.Circle((0,0),innerrad, fc='white')
#     670 # plt.gca().add_patch(circle)
#     671 labelnames.append(labelname)
#
# File ~/anaconda3/envs/omniplot310t/lib/python3.10/site-packages/omniplot/utils.py:148, in _baumkuchen(ax, start, theta, rin, rout, res, _color, edgecolor, linewidth, hatch)
#     146 if edgecolor!="":
#     147     ax.plot(xf, yf, zorder=2, color=edgecolor)
# --> 148 ax.fill(xf, yf, color=_color,edgecolor=edgecolor, linewidth=linewidth,hatch=hatch)
#
# File ~/anaconda3/envs/omniplot310t/lib/python3.10/site-packages/matplotlib/axes/_axes.py:5232, in Axes.fill(self, data, *args, **kwargs)
#    5230 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
#    5231 # _get_patches_for_fill returns a generator, convert it to a list.
# -> 5232 patches = [*self._get_patches_for_fill(*args, data=data, **kwargs)]
#    5233 for poly in patches:
#    5234     self.add_patch(poly)
#
# File ~/anaconda3/envs/omniplot310t/lib/python3.10/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/anaconda3/envs/omniplot310t/lib/python3.10/site-packages/matplotlib/axes/_base.py:544, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     542     return list(result)
#     543 else:
# --> 544     return [l[0] for l in result]
#
# File ~/anaconda3/envs/omniplot310t/lib/python3.10/site-packages/matplotlib/axes/_base.py:544, in <listcomp>(.0)
#     542     return list(result)
#     543 else:
# --> 544     return [l[0] for l in result]
#
# File ~/anaconda3/envs/omniplot310t/lib/python3.10/site-packages/matplotlib/axes/_base.py:537, in <genexpr>(.0)
#     534 else:
#     535     labels = [label] * n_datasets
# --> 537 result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     538                       {**kwargs, 'label': label})
#     539           for j, label in enumerate(labels))
#     541 if return_kwargs:
#     542     return list(result)
#
# File ~/anaconda3/envs/omniplot310t/lib/python3.10/site-packages/matplotlib/axes/_base.py:403, in _process_plot_var_args._makefill(self, x, y, kw, kwargs)
#     397 self._setdefaults(default_dict, kwargs)
#     399 seg = mpatches.Polygon(np.column_stack((x, y)),
#     400                        facecolor=facecolor,
#     401                        fill=kwargs.get('fill', True),
#     402                        closed=kw['closed'])
# --> 403 seg.set(**kwargs)
#     404 return seg, kwargs
#
# File ~/anaconda3/envs/omniplot310t/lib/python3.10/site-packages/matplotlib/artist.py:147, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     139 if not hasattr(cls.set, '_autogenerated_signature'):
#     140     # Don't overwrite cls.set if the subclass or one of its parents
#     141     # has defined a set method set itself.
#     142     # If there was no explicit definition, cls.set is inherited from
#     143     # the hierarchy of auto-generated set methods, which hold the
#     144     # flag _autogenerated_signature.
#     145     return
# --> 147 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     148 cls.set.__name__ = "set"
#     149 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File ~/anaconda3/envs/omniplot310t/lib/python3.10/site-packages/matplotlib/artist.py:1231, in Artist.set(self, **kwargs)
#    1227 def set(self, **kwargs):
#    1228     # docstring and signature are auto-generated via
#    1229     # Artist._update_set_signature_and_docstring() at the end of the
#    1230     # module.
# -> 1231     return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#
# File ~/anaconda3/envs/omniplot310t/lib/python3.10/site-packages/matplotlib/artist.py:1223, in Artist._internal_update(self, kwargs)
#    1216 def _internal_update(self, kwargs):
#    1217     """
#    1218     Update artist properties without prenormalizing them, but generating
#    1219     errors as if calling `set`.
#    1220
#    1221     The lack of prenormalization is to maintain backcompatibility.
#    1222     """
# -> 1223     return self._update_props(
#    1224         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225         "{prop_name!r}")
#
# File ~/anaconda3/envs/omniplot310t/lib/python3.10/site-packages/matplotlib/artist.py:1199, in Artist._update_props(self, props, errfmt)
#    1196             if not callable(func):
#    1197                 raise AttributeError(
#    1198                     errfmt.format(cls=type(self), prop_name=k))
# -> 1199             ret.append(func(v))
#    1200 if ret:
#    1201     self.pchanged()
#
# File ~/anaconda3/envs/omniplot310t/lib/python3.10/site-packages/matplotlib/patches.py:341, in Patch.set_edgecolor(self, color)
#     333 """
#     334 Set the patch edge color.
#     335
#    (...)
#     338 color : color or None
#     339 """
#     340 self._original_edgecolor = color
# --> 341 self._set_edgecolor(color)
#
# File ~/anaconda3/envs/omniplot310t/lib/python3.10/site-packages/matplotlib/patches.py:327, in Patch._set_edgecolor(self, color)
#     324         color = 'none'
#     325         set_hatch_color = False
# --> 327 self._edgecolor = colors.to_rgba(color, self._alpha)
#     328 if set_hatch_color:
#     329     self._hatch_color = self._edgecolor
#
# File ~/anaconda3/envs/omniplot310t/lib/python3.10/site-packages/matplotlib/colors.py:299, in to_rgba(c, alpha)
#     297     rgba = None
#     298 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 299     rgba = _to_rgba_no_colorcycle(c, alpha)
#     300     try:
#     301         _colors_full_map.cache[c, alpha] = rgba
#
# File ~/anaconda3/envs/omniplot310t/lib/python3.10/site-packages/matplotlib/colors.py:374, in _to_rgba_no_colorcycle(c, alpha)
#     370             raise ValueError(
#     371                 f"Invalid string grayscale value {orig_c!r}. "
#     372                 f"Value must be within 0-1 range")
#     373         return c, c, c, alpha if alpha is not None else 1.
# --> 374     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     375 # turn 2-D array into 1-D array
#     376 if isinstance(c, np.ndarray):
#
# ValueError: Invalid RGBA argument: ''

# %%
help(op.radialtree)
# Out:
# Help on function radialtree in module omniplot.plot:
#
# radialtree(df: pandas.core.frame.DataFrame, n_clusters: int = 3, x: str = '', variables: List = [], category: Union[str, List[str]] = [], ztransform: bool = True, save: str = '', distance_method='euclidean', tree_method='ward', title: str = '', y: list = [], **kwargs) -> Dict
#     Drawing a radial dendrogram with color labels.
#
#     Parameters
#     ----------
#     df : pandas DataFrame
#         A wide format data.
#
#
#     n_clusters: int, optional (default: 3)
#         Approximate number of clusters to produce
#     x: str, optional
#         the name of columns containing sample names. If not provided, the index will be considered sample names.
#     variables: list, optional
#         the name of columns containing variables to calculate the distances between samples
#     category: str or list of str
#         the column name of a category that is going to presented as colors around the dendrogram.
#     ztransform: bool=True,
#     save: str="",
#     distance_method="euclidean",
#     tree_method="ward",
#
#
#     show : bool
#         Whether or not to show the figure.
#     fontsize : float
#         A float to specify the font size
#     figsize : [x, y] array-like
#         1D array-like of floats to specify the figure size
#     palette : string
#         Matlab colormap name.
#     Returns
#     -------
#     dict: {"axes":ax, "clusters": clusters}
#
#     Raises
#     ------
#     Notes
#     -----
#     References
#     ----------
#     See Also
#     --------
#     Examples
#     --------

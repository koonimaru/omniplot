# %%
import seaborn as sns
from omniplot import plot as op

# %%
df=sns.load_dataset("penguins")
df=df.dropna(axis=0)
op.radialtree(df, category=["species","island","sex"])
# Out:
# [[  39.1   18.7  181.  3750. ]
#  [  39.5   17.4  186.  3800. ]
#  [  40.3   18.   195.  3250. ]
#  ...
#  [  50.4   15.7  222.  5750. ]
#  [  45.2   14.8  212.  5200. ]
#  [  49.9   16.1  213.  5400. ]]
# 0.45
# /home/koh/.local/lib/python3.8/site-packages/omniplot/plot.py:290: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Y = sch.linkage(D, method='ward')
# 1.4500000000000002
# [[0.         0.         0.         1.        ]
#  [0.         0.73853137 0.         1.        ]
#  [0.8        0.8        0.8        1.        ]]
# [[0.2        0.2        0.6        1.        ]
#  [0.99607843 0.99498039 0.59788235 1.        ]
#  [1.         1.         1.         1.        ]]
# [[0.22352941 0.23137255 0.4745098  1.        ]
#  [0.87058824 0.61960784 0.83921569 1.        ]]

# %%
help(op.radialtree)
# Out:
# Help on function radialtree in module omniplot.plot:
#
# radialtree(df, n_clusters: int = 3, category: List[str] = [], **kwargs)

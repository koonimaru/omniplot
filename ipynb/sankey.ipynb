# %%
import pandas as pd
from omniplot import networkplot as netp

# %%
df=pd.read_csv("../data/kmeans_result.csv")
netp.sankey_category(df, ["kmeans2","kmeans3","sex"],colormode="alternative",altcat="species")
# Out:
#      Unnamed: 0      UMAP1     UMAP2  kmeans2    species     sex  kmeans3
# 0           108   8.076429  4.130561        0     Adelie  Female        0
# 1           146   9.404985  6.439898        0  Chinstrap  Female        0
# 2           149   8.660819  5.461640        0  Chinstrap  Female        0
# 3           151   9.820534  7.486664        0  Chinstrap  Female        0
# 4           152   8.162106  3.614793        0  Chinstrap  Female        0
# ..          ...        ...       ...      ...        ...     ...      ...
# 328         324 -12.021644  0.373422        1     Gentoo    Male        1
# 329         326 -11.914089  0.630435        1     Gentoo    Male        1
# 330         327 -11.648980 -0.282223        1     Gentoo    Male        1
# 331         330 -11.399461 -0.166878        1     Gentoo    Male        1
# 332         332 -10.434985 -1.507699        1     Gentoo    Male        1
#
# [333 rows x 7 columns]
# <AxesSubplot:>

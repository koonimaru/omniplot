# %%
import seaborn as sns
from omniplot import plot as op
import numpy as np

# %%
df=sns.load_dataset("penguins")
df=df.dropna(axis=0)

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
res=op.stacked_barplot(df, x="species",hue="island", scale="absolute", test_pairs=[["Adelie","Gentoo"]])
# Out:
# mlp stands for -log10(p value)
# (-0.375, 2.375) (0.0, 153.3)
# [0.72727273 0.73385519]
# Biscoe [0.70391408 0.71028513]
# 0.7899031858851937
# (-0.375, 2.375) (0.0, 153.3)
# [0.72727273 0.9295499 ]
# Dream [0.61620258 0.78758769]
# 0.9068843512825764
# (-0.375, 2.375) (0.0, 153.3)
# [ 0.72727273 -0.06849315]
# Torgersen [ 0.99559453 -0.09376318]
# -0.0939011167826193

# %%
df=sns.load_dataset("penguins")
df=df.dropna(axis=0)
res=op.stacked_barplot(df, x="species",hue="island", scale="percentage")

# %%
res=op.stacked_barplot(df, x="species",hue="island", scale="fraction")

# %%
res=op.stacked_barplot(df, x="species",hue="sex", scale="percentage")

# %%
df2=sns.load_dataset("titanic")

# %%
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#df2=df2.replace(np.nan, "NA")

# %%
res=op.stacked_barplot(df2, x="class",hue="who", scale="percentage")

# %%
res=op.stacked_barplot(df2, x="class",hue="embark_town", scale="percentage")

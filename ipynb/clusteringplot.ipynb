# %%
import seaborn as sns
from omniplot import plot as op

# %%
df=sns.load_dataset("penguins")
df=df.dropna(axis=0)
features=["species","sex","bill_length_mm","bill_depth_mm","flipper_length_mm","body_mass_g"]
df=df[features]
dfnew=op.clusterplot(df,category=["species","sex"],method="kmeans",n_clusters="auto")
# Out:
# Top two optimal cluster No are: [2, 3]

# %%
df=sns.load_dataset("penguins")
df=df.dropna(axis=0)
features=["species","sex","bill_length_mm","bill_depth_mm","flipper_length_mm","body_mass_g"]
df=df[features]
dfnew=op.clusterplot(df,category=["species","sex"],method="hierarchical",n_clusters="auto")
# Out:
# /home/koh/.local/lib/python3.8/site-packages/omniplot/plot.py:1208: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Y = sch.linkage(D, method='ward')
# /home/koh/.local/lib/python3.8/site-packages/omniplot/plot.py:1320: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Y = sch.linkage(D, method='ward')
# [0.4043355882167816, 0.20521779855092367, 0.1206064447760582, 0.08790424466133118, 0.07373582820097606]
# Top two optimal cluster No are: 2, 3

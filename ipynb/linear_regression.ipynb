# %%
import seaborn as sns
from omniplot import plot as op
import pandas as pd

# %%
df=sns.load_dataset("penguins")
df=df.dropna(axis=0)
op.regression_single(df, x="bill_length_mm",y="body_mass_g", method="ransac",category="species")
# Out:
# {'axes': <Axes: title={'center': 'RANSAC regression, r2: 0.35, MSE: 559898.98\ny = 58.87 + 1278.36x, coefficient p-value: 3.67E-14'}, xlabel='bill_length_mm', ylabel='body_mass_g'>,
#  'coefficient': 58.86957604010605,
#  'intercept': 1278.3551905107156,
#  'coefficient_pval': 3.6652446589617664e-14,
#  'r2': 0.3474526112888375,
#  'fitted_model': RANSACRegressor(max_trials=1000, random_state=42)}

# %%
df=sns.load_dataset("penguins")
df=df.dropna(axis=0)
op.regression_single(df, x="bill_length_mm",y="body_mass_g", method="robust",category="species")
# Out:
# {'axes': <Axes: title={'center': 'Robust linear regression, r2: 0.35, MSE: 423340.06\ny = 92.78 + 146.53x , p-values: coefficient 0.00,         intercept 0.63'}, xlabel='bill_length_mm', ylabel='body_mass_g'>,
#  'coefficient': 92.78064164006865,
#  'intercept': 146.5297988868342,
#  'coefficient_pval': 9.330037623092594e-42,
#  'r2': 0.3474526112888375,
#  'fitted_model': <statsmodels.robust.robust_linear_model.RLMResultsWrapper at 0x7f0929624370>}

# %%
df=sns.load_dataset("penguins")
df=df.dropna(axis=0)
op.regression_single(df, x="bill_length_mm",y="body_mass_g", method="lasso",category="species")
# Out:
# 6.5376660813454635 86.7898283032082
# {'axes': <AxesSubplot: title={'center': 'OLS (sqrt_lasso), r2: 0.35, MSE: 421823.22\ny = 86.79 + 388.93x, coefficient p-value: 7.71E-33'}, xlabel='bill_length_mm', ylabel='body_mass_g'>,
#  'coefficient': 86.7898283032082,
#  'intercept': 388.93144038060746,
#  'coefficient_pval': 7.712891078912778e-33,
#  'r2': 0.3474526112888375,
#  'fitted_model': <statsmodels.base.elastic_net.RegularizedResultsWrapper at 0x7efc919482b0>}

# %%
df=sns.load_dataset("penguins")
df=df.dropna(axis=0)
op.regression_single(df, x="bill_length_mm",y="body_mass_g", method="elastic_net",category="species")
# Out:
# 6.910175703333428 46.38173205794367
# {'axes': <Axes: title={'center': 'OLS (elastic_net), r2: 0.35, MSE: 471262.84\ny = 46.38 + 2193.98x, coefficient p-value: 4.17E-11'}, xlabel='bill_length_mm', ylabel='body_mass_g'>,
#  'coefficient': 46.38173205794367,
#  'intercept': 2193.9834014426524,
#  'coefficient_pval': 4.171574102679969e-11,
#  'r2': 0.3474526112888375,
#  'fitted_model': <statsmodels.base.elastic_net.RegularizedResultsWrapper at 0x7f092958c370>}

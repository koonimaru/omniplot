# %%
import seaborn as sns
from omniplot import plot as op
import numpy as np
import pandas as pd

# %% [markdown]
# Download data for demonstration. </br>
# ```bash
# wget https://raw.githubusercontent.com/owid/energy-data/master/owid-energy-data.csv
# ````

# %%
# the file may be downloaded from jupyter
# !wget https://raw.githubusercontent.com/owid/energy-data/master/owid-energy-data.csv
# Out:
# --2023-02-21 16:18:19--  https://raw.githubusercontent.com/owid/energy-data/master/owid-energy-data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8001::154, 2606:50c0:8002::154, 2606:50c0:8003::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8001::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8310494 (7.9M) [text/plain]
# Saving to: ‘owid-energy-data.csv’
#
# owid-energy-data.cs 100%[===================>]   7.92M  6.21MB/s    in 1.3s
#
# 2023-02-21 16:18:21 (6.21 MB/s) - ‘owid-energy-data.csv’ saved [8310494/8310494]

# %%
f="owid-energy-data.csv"
df=pd.read_csv(f)
_df=df.loc[df["country"]=="United States"]
cols=['biofuel_consumption',
     'coal_consumption',
     'gas_consumption',
     'hydro_consumption',
     'nuclear_consumption',
     'oil_consumption',
     'other_renewable_consumption',
     'solar_consumption',
     'wind_consumption']
op.stackedlines(df=_df, x="year",y=cols, title="United States", ylabel="terawat per hour", remove_all_zero=True,show_values=True)

# %%
op.stackedlines(df=_df, x="year",y=cols, title="United States", ylabel="terawat per hour", remove_all_zero=True,show_values=True, inverse=True)

# %%
# show years with no record
op.stackedlines(df=_df, x="year",y=cols, title="United States",show_values=True)

# %%
#Do not show percentages
op.stackedlines(df=_df, x="year",y=cols, title="United States", remove_all_zero=True,show_values=False)

# %%
# without sorting
op.stackedlines(df=_df, x="year",y=cols, title="United States", remove_all_zero=True,show_val=False,sort=False)

# %%
_df=_df.reset_index()

# %%
_df.iloc[90:][["year"]+cols]
# Out:
#      year  biofuel_consumption  coal_consumption  gas_consumption  \
# 90   1990               16.733          5337.998         5170.609
# 91   1991               19.389          5287.613         5283.972
# 92   1992               22.045          5324.031         5463.509
# 93   1993               25.759          5522.452         5599.419
# 94   1994               28.846          5543.144         5731.081
# 95   1995               30.942          5593.053         5979.829
# 96   1996               22.194          5847.301         6088.898
# 97   1997               28.104          5970.778         6125.315
# 98   1998               31.054          6029.338         6021.791
# 99   1999               32.287          6020.095         6042.628
# 100  2000               37.003          6286.536         6283.907
# 101  2001               39.312          6101.315         6006.580
# 102  2002               46.962          6098.454         6201.112
# 103  2003               63.713          6214.537         6021.900
# 104  2004               80.427          6254.982         6046.277
# 105  2005               93.975          6346.957         5951.930
# 106  2006              131.700          6249.683         5865.778
# 107  2007              166.344          6333.850         6241.383
# 108  2008              227.219          6233.055         6288.912
# 109  2009              258.137          5482.376         6176.281
# 110  2010              296.773          5800.542         6481.935
# 111  2011              321.360          5473.071         6582.108

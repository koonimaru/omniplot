# %%
import seaborn as sns
from omniplot import plot as op

# %%
df=sns.load_dataset("penguins")
df=df.dropna(axis=0)
features=["species","bill_length_mm","bill_depth_mm","flipper_length_mm","body_mass_g"]
df=df[features]
res=op.decomplot(df,category="species",method="pca", markers=True)

# %%
res=op.decomplot(df,category="species",method="nmf")
# Out:
# /home/koh/anaconda3/envs/omniplot310t/lib/python3.10/site-packages/sklearn/decomposition/_nmf.py:1665: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/koh/vscode/omniplot/ipynb/decomposition.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/koh/vscode/omniplot/ipynb/decomposition.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> res=op.decomplot(df,category="species",method="nmf")
#
# File ~/anaconda3/envs/omniplot310t/lib/python3.10/site-packages/omniplot/scatter.py:1079, in decomplot(df, variables, category, method, component, arrow_color, arrow_text_color, show, explained_variance, arrow_num, figsize, regularization, pcapram, nmfparam, save, title, markers, saveparam, ax, palette, size)
# ...

# %%
import seaborn as sns
from omniplot import plot as op

# %%
df=sns.load_dataset("penguins")
df=df.dropna(axis=0)
features=["species","bill_length_mm","bill_depth_mm","flipper_length_mm","body_mass_g"]
df=df[features]
res=op.decomplot(df,category="species",method="pca", markers=True)
# Out:
# /home/koh/vscode/omniplot/omniplot/scatter.py:87: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   sc=ax.scatter(_dfnew[x], _dfnew[y],
# /home/koh/vscode/omniplot/omniplot/scatter.py:87: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   sc=ax.scatter(_dfnew[x], _dfnew[y],
# /home/koh/vscode/omniplot/omniplot/scatter.py:87: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   sc=ax.scatter(_dfnew[x], _dfnew[y],
# /home/koh/vscode/omniplot/omniplot/scatter.py:87: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   sc=ax.scatter(_dfnew[x], _dfnew[y],
# /home/koh/vscode/omniplot/omniplot/scatter.py:87: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   sc=ax.scatter(_dfnew[x], _dfnew[y],
# /home/koh/vscode/omniplot/omniplot/scatter.py:87: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   sc=ax.scatter(_dfnew[x], _dfnew[y],
# /home/koh/vscode/omniplot/omniplot/scatter.py:87: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   sc=ax.scatter(_dfnew[x], _dfnew[y],
# /home/koh/vscode/omniplot/omniplot/scatter.py:87: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   sc=ax.scatter(_dfnew[x], _dfnew[y],
# /home/koh/vscode/omniplot/omniplot/scatter.py:87: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   sc=ax.scatter(_dfnew[x], _dfnew[y],

# %%
res=op.decomplot(df,category="species",method="nmf")
# Out:
# /home/koh/.local/lib/python3.10/site-packages/sklearn/decomposition/_nmf.py:1665: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(

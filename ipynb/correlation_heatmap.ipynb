# %%
import seaborn as sns
from omniplot import plot as op

# %%
# %config InlineBackend.print_figure_kwargs={'bbox_inches': None}

# %%
df = sns.load_dataset("penguins")
df = df.dropna(axis=0)
res = op.correlation(
    df, category=["species", "island", "sex"], method="pearson", ztransform=True
)

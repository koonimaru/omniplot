# %%
import pandas as pd
from omniplot import networkplot as netp
import seaborn as  sns

# %%
df=sns.load_dataset("penguins")
df=df.dropna(axis=0)
df=df.reset_index()
res=netp.correlation(df, category=["species", "island","sex"], 
            method="pearson", 
            ztransform=True,
            clustering ="louvain",show_edges=True, bundle=False)
# Out:
# correlation calc:  0.0015568733215332031

# %%
df=sns.load_dataset("penguins")
df=df.dropna(axis=0)
df=df.reset_index()
res=netp.correlation(df, 
                     category=["species", "island","sex"], 
            method="pearson", 
            ztransform=True,
            clustering ="louvain",
                     edge_cmap="coolwarm",
                     show_edges=True, 
                     bundle=False)
# Out:
# correlation calc:  0.0009591579437255859

# %%
res=netp.correlation(df, category=["species", "island","sex"], 
            method="pearson", 
            ztransform=True,
            clustering ="louvain",show_edges=False, bundle=True)
# Out:
# correlation calc:  0.0020341873168945312

# %%
res=netp.correlation(df, category=["species", "island","sex"], 
            method="pearson", 
            ztransform=True,
            clustering ="louvain",show_edges=False, bundle=True,
                    rows_cols=[2,2],figsize=[6,6])
# Out:
# correlation calc:  0.0015048980712890625
